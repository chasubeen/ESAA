# %% [markdown]
# <a href="https://colab.research.google.com/github/chasubeen/ESAA_8th_YB/blob/Week_3/Do_it!%20%ED%8C%90%EB%8B%A4%EC%8A%A4_04.%20%EA%B7%B8%EB%9E%98%ED%94%84%20%EA%B7%B8%EB%A6%AC%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### 내장 패키지 & 버전 확인

# !pip list

# %% [markdown]
# - seaborn: 0.12.2

# %% [markdown]
# # **1. 데이터 시각화가 필요한 이유**

# %% [markdown]
# ## **1-1. 앤스콤 4분할 그래프 살펴보기**

# %% [markdown]
# ### **1) 앤스콤 데이터 집합 불러오기**

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns 

anscombe = sns.load_dataset("anscombe") 
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# ### **2) matplotlib으로 그래프 그리기**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# 첫 번쨰 데이터 그룹 추출

dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %%
# 시각화

plt.plot(dataset_1['x'], dataset_1['y'])

# %%
# 점 그래프로 그리기

plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %% [markdown]
# ## **1-2. 한 번에 4개의 그래프 그리기**

# %%
# 데이터 저장

dataset_2 = anscombe[anscombe['dataset'] == 'II'] 
dataset_3 = anscombe[anscombe['dataset'] == 'III'] 
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
# 격자가 위치할 기본 틀 생성

fig = plt.figure()

# %%
# 그래프 격자 그리기

axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
# 그래프 그리기

axes1.plot(dataset_1['x'], dataset_1['y'], 'o') 
axes2.plot(dataset_2['x'], dataset_2['y'], 'o') 
axes3.plot(dataset_3['x'], dataset_3['y'], 'o') 
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig

# %%
# 그래프 격자에 제목 추가하기

axes1.set_title("dataset_1") 
axes2.set_title("dataset_2")
axes3.set_title("dataset_3") 
axes4.set_title("dataset_4")

fig

# %%
# 기본 틀에 제목 추가

fig.suptitle("Anscombe Data")

fig

# %%
# 레이아웃 조절

fig.tight_layout()
fig

# %% [markdown]
# # **2. matplotlib 라이브러리 자유자재로 사용하기**

# %% [markdown]
# ## **2-1. 기초 그래프 그리기**

# %%
### 데이터 준비하기

tips = sns.load_dataset("tips") 
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
### 틀, 격자 준비하기

fig = plt.figure() # 기본 틀
axes1 = fig.add_subplot(1, 1, 1) # 격자 구성

# %%
### 히스토그램 그리기

axes1.hist(tips['total_bill'], bins=10) 
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency') 
axes1.set_ylabel('Total Bill') 

fig

# %%
### 산점도 그래프 그리기

scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot(1, 1, 1) 
axes1.scatter(tips['total_bill'], tips['tip']) 
axes1.set_title('Scatterplot of Total Bill vs Tip') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
### 박스 그래프 그리기

boxplot = plt.figure() 
axes1 = boxplot.add_subplot(1, 1, 1) 

axes1.boxplot( 
    [tips[tips['sex'] == 'Female']['tip'], 
     tips[tips['sex'] == 'Male']['tip']], 
    labels=['Female', 'Male'])

axes1.set_xlabel('Sex') 
axes1.set_ylabel('Tip') 
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# ## **2-2. 다변량 그래프 그리기**

# %% [markdown]
# ### **ㆍ 다변량 산점도 그래프 그리기**

# %%
### 문자열을 정수로 치환하는 함수

def recode_sex(sex):
    if sex == 'Female':
        return 0 
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex) # 문자형 -> 수치형

# %%
### 다변량 산점도 그래프 그리기

scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot(1, 1, 1) 
axes1.scatter(
    x = tips['total_bill'], 
    y = tips['tip'],    
    s = tips['size'] * 10,    
    c = tips['sex_color'],
    alpha = 0.5)

axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# # **3. Seaborn 라이브러리 자유자재로 사용하기**

# %% [markdown]
# ## **3-1. 단변량 그래프 그리기 - 히스토그램**

# %%
### 데이터 준비하기

import seaborn as sns

tips = sns.load_dataset("tips")

# %%
### 히스토그램 그리기

ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <ipython-input-23-b4a04e70c42e>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'])
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'],kde = False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <ipython-input-24-f43472bf14cb>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'],kde = False)
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], hist=False) 
ax.set_title('Total Bill Density') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Unit Probability')
# Out:
# <ipython-input-25-e78c4e0ad749>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], hist=False)
# Text(0, 0.5, 'Unit Probability')

# %%
### 러그 그래프 출력

hist_den_rug, ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], rug=True) 
ax.set_title('Total Bill Histogram with Density and Rug Plot') 
ax.set_xlabel('Total Bill')
# Out:
# <ipython-input-26-2b413daf5967>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], rug=True)
# Text(0.5, 0, 'Total Bill')

# %% [markdown]
# ## **3-2. countplot 그리기**

# %%
ax = plt.subplots() 
ax = sns.countplot(x = 'day',  data = tips) # 모두 다 keyword 매개변수로 적어줘야 에러 x
ax.set_title('Count of days') 
ax.set_xlabel('Day of the Week') 
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## **3-3. 산점도 그래프 그리기**

# %%
ax = plt.subplots() 
ax = sns.regplot(x = 'total_bill', y = 'tip', data = tips) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
### 회귀선 x

ax = plt.subplots() 
ax = sns.regplot(x = 'total_bill', y = 'tip', data = tips, fit_reg = False) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
### jointplot 메서드 활용하기

joint = sns.jointplot(x = 'total_bill', y = 'tip', data = tips) 
joint.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize = 10, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
### 육각 그래프 그리기

hexbin = sns.jointplot(x = "total_bill", y = "tip", data = tips, kind = "hex") 
hexbin.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize = 10, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# ## **3-4. 이차원 밀집도 그리기**

# %%
kde, ax = plt.subplots() 

# version 차이로 인해 일부 옵션 변경
ax = sns.kdeplot(data = tips, x = 'total_bill', y = 'tip', shade = True) 
ax.set_title('Kernel Density Plot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# <ipython-input-32-fd27c5df274c>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(data = tips, x = 'total_bill', y = 'tip', shade = True)
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ## **3-5. 바 그래프 그리기**

# %%
ax = plt.subplots() 
ax = sns.barplot(x = 'time', y = 'total_bill', data = tips) 
ax.set_title('Bar plot of average total bill for time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# ## **3-6. 박스 그래프 그리기**

# %%
ax = plt.subplots() 
ax = sns.boxplot(x = 'time', y = 'total_bill', data = tips) 
ax.set_title('Boxplot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ## **3-7. 바이올린 그래프**

# %%
ax = plt.subplots() 
ax = sns.violinplot(x = 'time', y = 'total_bill', data = tips) 
ax.set_title('Violin plot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ## **3-8. 관계 그래프 그리기**

# %%
fig = sns.pairplot(tips)

# %%
### 위치 지정

pair_grid = sns.PairGrid(tips) 
pair_grid = pair_grid.map_upper(sns.regplot) 
pair_grid = pair_grid.map_lower(sns.kdeplot) 
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) 
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ## **3-9. 다변량 그래프 그리기**

# %% [markdown]
# ### **a. 색상 추가**

# %%
### 색상 추가

violin, ax = plt.subplots() 
ax = sns.violinplot(x = 'time', y = 'total_bill', hue = 'sex', 
                    data = tips, split = True) 
plt.show()

# %%
### 산점도 그래프 그리기

scatter = sns.lmplot(x = 'total_bill', y = 'tip', data = tips, 
                     hue = 'sex', fit_reg = False) 
plt.show()

# %%
fig = sns.pairplot(tips, hue = 'sex')

# %% [markdown]
# ### **b. 산점도 그래프의 크기/모양 조절**

# %% [markdown]
# - 교재의 예제대로 하면 에러 발생
# - 에러 발생 이유: Seaborn 버전 변경 시 업데이트 내용 때문(현재 사용중인 버전: 0.12.2)
# - 본인의 개발환경에서 버전 확인
# ```
# !pip list | grep seaborn    # 내장 패키지 중 seaborn만 확인
# ```
# - [Seaborn 공식 Github_Issue checking](https://github.com/mwaskom/seaborn/issues/2621)
# ---
# ※
# - Seaborn을 통해 시각화를 시키다 보면 버전 업데이트로 인해 이전과 함수들이 많이 달라진 것을 확인할 수 있음
#   - 공식 API와 stack overflow 등 구글링을 생활화하자..
#   (~영어싫어~)
# - [Seaborn 공식 API 문서]()

# %%
scatter = sns.relplot(data = tips, x = 'total_bill', y = 'tip', 
                      hue = 'sex', s = tips['size'] * 10)
plt.show()

# %% [markdown]
# - Implot의 경우 ```hue``` 옵션을 사용할 수 없음
#   - replot을 활용, 일부 parameter를 상황에 맞게 변경
#   (최대한 교재랑 비슷하게 설정해 둠)

# %%
scatter = sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex', 
                     style = 'sex', s = tips['size'] * 10) 
plt.show()

# %% [markdown]
# ### **c. 여러 데이터 그룹에 대한 그래프 그리기**

# %%
### 그룹 구분 x

anscombe_plot = sns.lmplot(x = 'x', y = 'y', data = anscombe, fit_reg = False)

# %%
### 그룹 구분 O

anscombe_plot = sns.lmplot(x = 'x', y = 'y', data = anscombe, 
                           fit_reg = False, col = 'dataset', col_wrap = 2)

# %% [markdown]
# ### **✔ FacetGrid 클래스 활용**

# %%
### 양탄자 그래프 그리기

facet = sns.FacetGrid(tips, col = 'time') 
facet.map(sns.distplot, 'total_bill', rug = True)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
### 다변량 그래프 그리기

facet = sns.FacetGrid(tips, col = 'day', hue = 'sex') 
facet = facet.map(plt.scatter, 'total_bill', 'tip') 
facet = facet.add_legend()

# %%
### 더 많은 변수를 가지는 다변량 그래프
# 2 * 2 격자 그래프 그리기

facet = sns.FacetGrid(tips, col = 'time', row = 'smoker', hue = 'sex') 
facet.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# # **4. 데이터 프레임과 시리즈로 그래프 그리기**

# %%
### 히스토그램 그리기

fig, ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
### 투명도, 축 간격 조절

fig, ax = plt.subplots() 
ax = tips[['total_bill', 'tip']].plot.hist(alpha = 0.5, bins = 20, ax = ax)

# %%
### 밀집도(kde) 그래프

fig, ax = plt.subplots() 
ax = tips['tip'].plot.kde()

# %%
### 산점도 그래프

fig, ax = plt.subplots() 
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
### 육각 그래프

fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)

# %%
# 육각형 크기 조정

fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x = 'total_bill', y = 'tip', gridsize = 10, ax = ax)

# %%
### 박스 그래프

fig, ax = plt.subplots() 
ax = tips.plot.box(ax=ax)

# %% [markdown]
# # **5. 그래프에 스타일 적용**

# %%
### 원본 그래프

fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
### whitegrid로 스타일 설정

sns.set_style('whitegrid') 
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
### 모든 스타일을 하나씩 적용해보기

fig = plt.figure() 
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks'] 
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style) 
        
fig.tight_layout()

# %% [markdown]
# # **References**
# - [Seaborn API](https://seaborn.pydata.org/api.html#)
# - [Matplotlib API](https://matplotlib.org/stable/api/index.html)
